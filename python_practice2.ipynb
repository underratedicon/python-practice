# %% [markdown]
# <a href="https://colab.research.google.com/github/underratedicon/python-practice/blob/main/python_practice2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= 10
b= 5
sum = a+b
difference = a-b
product = a*b
division = a/b

print("Sum:",sum)
print("Difference: ",difference)
print("Product: ",product)
print("Division: ",division)
# Out:
# Sum: 15
# Difference:  5
# Product:  50
# Division:  2.0

# %%
print(f"The sum of the two numbers {a}, {b} is {sum}")
# Out:
# The sum of the two numbers 10, 5 is 15

# %%
x=13//2
print(x)
y= 13%2
print(y)
# Out:
# 6
# 1

# %%
x= 10
y = 5

is_greater = x>y
is_equal = x==y
is_not_equal = x!=y

print("is x greater than y?", is_greater)
print("is x equal y?", is_equal)
print("is x not equal to y?", is_not_equal)
# Out:
# is x greater than y? True
# is x equal y? False
# is x not equal to y? True

# %%
name= "Peter"
age= 28
is_student = True

print(f"{name}'s age is {age}. He is a Student is {is_student}")
# Out:
# Peter's age is 28. He is a Student is True

# %%
def greet(name):
    return "Hello, " + name + "!"

my_name = input("Enter your name: ")
print(greet(my_name))
# Out:
# Enter your name: Peter chukwu
# Hello, Peter chukwu!

# %%
def add_numbers(a, b):
    return a + b

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

addition_value = add_numbers(a, b)
print(f"The result of addition for {a}, {b} is {addition_value}")
# Out:
# Enter first number: 2
# Enter second number: 3
# The result of addition for 2, 3 is 5

# %%
def add_numbers(a, b):
    return a + b

a = eval(input("Enter first number: "))
b = eval(input("Enter second number: "))

addition_value = add_numbers(a, b)
print(f"The result of addition for {a}, {b} is {addition_value}")
# Out:
# Enter first number: 2.34
# Enter second number: 5.67
# The result of addition for 2.34, 5.67 is 8.01

# %%
message = "Hello, World"

length = len(message)
uppercase = message.upper()
lowercase = message.lower()
substring = message[7:12]

print("Original message: ", message)
print("The length is: ", length)
print("Upper case: ", uppercase)
print("Lower case: ", lowercase)
print("Part of the message is: ", substring)
# Out:
# Original message:  Hello, World
# The length is:  12
# Upper case:  HELLO, WORLD
# Lower case:  hello, world
# Part of the message is:  World

# %%
Last = input("Enter the last name, last name: ")
First = input("Enter the last name, first name: ")

print(f"{Last}, {First}")
# Out:
# Enter the last name, last name: peter chukwu
# Enter the last name, first name: chukwu
# peter chukwu, chukwu

# %%
age = int(input("Enter your age: "))
print("You will be", age + 1, "years old next year.")
# Out:
# Enter your age: 28
# You will be 29 years old next year.

# %%
num1 = float(input("Enter a number: "))
num2 = float(input("Enter another number: "))

sum_result = num1 + num2
print("Sum:", sum_result)
# Out:
# Enter a number: 3
# Enter another number: 3
# Sum: 6.0

# %%
city = input("Enter your city: ")
country = input("Enter your country: ")

location = city + ", " + country
print("You are in:", location)
# Out:
# Enter your city: Hamden
# Enter your country: USA
# You are in: Hamden, USA

# %%
name, age = input("Enter your name and age separated by space: ").split()

print(f"my name is {name} and my age is {age}")
# Out:
# Enter your name and age separated by space: Peter, 28
# my name is Peter, and my age is 28
